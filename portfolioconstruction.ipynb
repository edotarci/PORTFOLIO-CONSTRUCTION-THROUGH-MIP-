# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gurobipy as gp
from gurobipy import GRB

# %%
def MIP(N, S, L, w_0, w_t, alpha, lq, vol, M, ls, cs):
    
    L_sec = L[0:S]
    L_names = L[S]
    L_tickets = L[S+1]
    L_alpha = L[S+2]
    L_illiquidity = L[S+3]
    L_tc = L[S+4]

    #gp.Env.setParam("OutputFlag",0)
    
        #Model
    m = gp.Model("MIP")
    
    #Variables
    Names = m.addMVar((N, 1), vtype=GRB.BINARY, name="Names")
    Tickets = m.addMVar((N, 1), vtype=GRB.BINARY, name="Tickets")
    Weights = m.addMVar((N, 1), lb=0.0, vtype=GRB.CONTINUOUS, name="Weigths")

    Y = m.addMVar((N, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="Y")
    F = m.addMVar((N, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="F")
    X = m.addMVar((S, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="X")

    x_1 = m.addMVar((N, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="x_1")
    x_2 = m.addMVar((N, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="x_2")
    x_3 = m.addMVar((N, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="x_3")

    z_1 = m.addMVar((N, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="z_1")
    z_2 = m.addMVar((N, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="z_2")
    z_3 = m.addMVar((N, 1), lb = 0.0, vtype=GRB.CONTINUOUS, name="z_3")

    #Constraints

    #Sum of Weights
    m.addConstr(Weights.sum() == 1, 'Sum of weights')
    #Constraints on Y[i]
    m.addConstrs((Weights[i] - w_t[i] <= Y[i] for i in range(N)), name='Y+')
    m.addConstrs((-(Weights[i] - w_t[i]) <= Y[i] for i in range(N)), name='Y-')
    #Constraints on F[i]
    m.addConstrs((Weights[i] - w_0[i] <= F[i] for i in range(N)), name='F+')
    m.addConstrs((-(Weights[i] - w_0[i]) <= F[i] for i in range(N)), name='F-')    
    #Constraints with X[s]
    m.addConstrs((X[s] >= np.sum(M[s][i]*(Weights[i] - w_t[i]) for i in range(N)) for s in range(S)), name='X+')
    m.addConstrs((X[s] >= -np.sum(M[s][i]*(Weights[i] - w_t[i]) for i in range(N)) for s in range(S)), name='X-')
    #Binary flag for Names
    m.addConstrs((Weights[i] <= Names[i] for i in range(N)), name='W<N')
    #Binary flag for Tickets
    m.addConstrs((F[i] <= Tickets[i] for i in range(N)), name='F<T')
    #Constraints for Liquidity
    m.addConstrs((Weights[i] == x_1[i] + x_2[i] + x_3[i] for i in range(N)),name='W=x1+x2+x3')
    #Components of Liquidity Constraints
    m.addConstrs((x_1[i] <= lq[i] for i in range(N)), name='x1')
    m.addConstrs((x_2[i] <= lq[i] for i in range(N)), name='x2')
    m.addConstrs((x_3[i] <= 2*lq[i] for i in range(N)), name='x3')
    #Constraints for Volatility
    m.addConstrs((F[i] == z_1[i] + z_2[i] + z_3[i] for i in range(N)), name='F=z1+z2+z3')
    #Components of Volatility Constraints
    m.addConstrs((z_1[i] <= 0.1*vol[i] for i in range(N)), name='z1')
    m.addConstrs((z_2[i] <= 0.2*vol[i] for i in range(N)), name='z2')
    m.addConstrs((z_3[i] <= 0.2*vol[i] for i in range(N)), name='z3')

    #Objective Function
    m.setObjective((Y.sum() + 
                    np.sum(L_sec[i] * X[i] for i in range(S)) +
                    L_names*Names.sum() + 
                    L_tickets*Tickets.sum() - 
                    L_alpha*np.sum(alpha[i]*Weights[i] for i in range(N)) + 
                    L_illiquidity*np.sum((ls[i][0]*x_1[i] + ls[i][1]*x_2[i] + ls[i][2]*x_3[i]) for i in range(N)) + 
                    L_tc*np.sum((cs[i][0]*z_1[i] + cs[i][1]*z_2[i] + cs[i][2]*z_3[i]) for i in range(N)))
                    , GRB.MINIMIZE)

    m.optimize()
    
    for v in m.getVars():
        print(f'{v.VarName} = {v.x}')

    if m.Status == GRB.INFEASIBLE:
        m.computeIIS()
        print('\nThe following constraints and variables are in the IIS:')
        for c in m.getConstrs():
            if c.IISConstr: print(f'\t{c.constrname}: {m.getRow(c)} {c.Sense} {c.RHS}')


    return Weights.x

# %%
data = pd.read_excel(r"/Users/edotarci/Desktop/exchange HK/ieda_op_research/Project/DATA.xlsx", sheet_name="GENERAL") 

N = pd.DataFrame(data, columns=["N"])
N = int(N.dropna().to_numpy()[0])

S = pd.DataFrame(data, columns=["S"])
S = int(S.dropna().to_numpy()[0])

L = pd.DataFrame(data, columns=["L"])
L = L.dropna().to_numpy()

data1 = pd.read_excel(r"/Users/edotarci/Desktop/exchange HK/ieda_op_research/Project/DATA.xlsx", sheet_name="WT in time") 
w_t = pd.DataFrame(data1)
w_t = w_t.dropna().to_numpy()

data2 = pd.read_excel(r"/Users/edotarci/Desktop/exchange HK/ieda_op_research/Project/DATA.xlsx", sheet_name="VOLUME") 
vol = pd.DataFrame(data2)
vol = vol.dropna().to_numpy()

data3 = pd.read_excel(r"/Users/edotarci/Desktop/exchange HK/ieda_op_research/Project/DATA.xlsx", sheet_name="alpha") 
alpha = pd.DataFrame(data3)
alpha = alpha.dropna().to_numpy()

lq = pd.DataFrame(data, columns=["LQ"])
lq = lq.dropna().to_numpy()


M = pd.DataFrame(data, columns=["0003.HK","0066.HK","0386.HK","0270.HK","0175.HK",
                                "0168.HK","0151.HK","2319.HK","2318.HK","2202.HK",
                                "1929.HK","1928.HK","1398.HK","1128.HK","1093.HK",
                                "0941.HK","0914.HK","0857.HK","0753.HK","0700.HK"])
M = M.dropna().to_numpy()


w_0 = np.ones([N,1])/N
w_f = np.zeros([N,49])

names = ["0003.HK","0066.HK","0386.HK","0270.HK","0175.HK",
                                "0168.HK","0151.HK","2319.HK","2318.HK","2202.HK",
                                "1929.HK","1928.HK","1398.HK","1128.HK","1093.HK",
                                "0941.HK","0914.HK","0857.HK","0753.HK","0700.HK"]

for i in range(48):
    w_t_loop = w_t[:,i]
    vol_loop = vol[:,i]

    alpha_loop = np.transpose(alpha[i][:])

    #I suppose that both are following the law f(x) = x^2 for ease of use
    ls = np.concatenate([np.power(lq,2), np.power(2*lq,2), np.power(4*lq,2)], axis=1)

    cs = np.zeros([3,20])
    cs[:][0] = np.transpose(np.power(0.1*vol_loop,2))
    cs[:][1] = np.transpose(np.power(0.3*vol_loop,2))
    cs[:][2] = np.transpose(np.power(0.5*vol_loop,2))

    cs = np.transpose(cs)
    
    print(cs)

    w_f[:,i+1] = MIP(N, S, L, w_0, w_t_loop, alpha_loop, lq, vol_loop, M, ls, cs).reshape(-1)
    w_0 = w_f[:,i]
# Out:
# [[2.61250062e-03 2.35125056e-02 6.53125154e-02]
#  [1.12784223e-03 1.01505800e-02 2.81960557e-02]
#  [5.86005572e-03 5.27405015e-02 1.46501393e-01]
#  [3.77954624e-03 3.40159162e-02 9.44886561e-02]
#  [3.15332501e-03 2.83799251e-02 7.88331254e-02]
#  [4.31968613e-03 3.88771752e-02 1.07992153e-01]
#  [7.24451625e-03 6.52006462e-02 1.81112906e-01]
#  [2.14138184e-03 1.92724366e-02 5.35345461e-02]
#  [3.74388005e-02 3.36949205e-01 9.35970013e-01]
#  [5.14200253e-02 4.62780228e-01 1.28550063e+00]
#  [3.40777036e-02 3.06699332e-01 8.51942589e-01]
#  [2.03760141e-03 1.83384127e-02 5.09400352e-02]
#  [1.24118820e-02 1.11706938e-01 3.10297051e-01]
#  [2.87681736e-04 2.58913562e-03 7.19204339e-03]
#  [8.62695650e-04 7.76426085e-03 2.15673913e-02]
#  [4.28948713e-03 3.86053842e-02 1.07237178e-01]
#  [7.71419334e-03 6.94277400e-02 1.92854833e-01]
#  [4.13156344e-03 3.71840710e-02 1.03289086e-01]
#  [1.03065537e-03 9.27589830e-03 2.57663842e-02]
#  [2.62327448e-03 2.36094703e-02 6.55818619e-02]]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-17
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_6564/2338374397.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   N = int(N.dropna().to_numpy()[0])
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_6564/2338374397.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   S = int(S.dropna().to_numpy()[0])
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_6564/3753500305.py:43: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   m.addConstrs((X[s] >= np.sum(M[s][i]*(Weights[i] - w_t[i]) for i in range(N)) for s in range(S)), name='X+')
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 231 columns and 602 nonzeros
# Model fingerprint: 0x499addd1
# Variable types: 191 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-08, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-03, 1e+00]
# Presolve removed 179 rows and 59 columns
# Presolve time: 0.00s
# Presolved: 124 rows, 172 columns, 395 nonzeros
# Variable types: 143 continuous, 29 integer (29 binary)
# Found heuristic solution: objective 2.8688456
#
# Root relaxation: objective 2.175192e+00, 101 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.17519    0    4    2.86885    2.17519  24.2%     -    0s
# H    0     0                       2.5004061    2.17519  13.0%     -    0s
# H    0     0                       2.4519325    2.17519  11.3%     -    0s
# H    0     0                       2.4241345    2.17519  10.3%     -    0s
# H    0     0                       2.4163608    2.17519  10.0%     -    0s
# H    0     0                       2.3778886    2.17519  8.52%     -    0s
# H    0     0                       2.3763537    2.35402  0.94%     -    0s
#      0     0    2.35402    0    4    2.37635    2.35402  0.94%     -    0s
# H    0     0                       2.3635123    2.35402  0.40%     -    0s
# H    0     0                       2.3619727    2.36117  0.03%     -    0s
#      0     0    2.36197    0    2    2.36197    2.36197  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 1
#   Implied bound: 4
#   Clique: 1
#   MIR: 1
#   Flow cover: 4
#
# Explored 1 nodes (130 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 2.36197 2.36351 2.37635 ... 2.86885
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.361972732956e+00, best bound 2.361972732956e+00, gap 0.0000%
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_6564/3753500305.py:44: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   m.addConstrs((X[s] >= -np.sum(M[s][i]*(Weights[i] - w_t[i]) for i in range(N)) for s in range(S)), name='X-')
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_6564/3753500305.py:64: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   np.sum(L_sec[i] * X[i] for i in range(S)) +
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_6564/3753500305.py:67: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   L_alpha*np.sum(alpha[i]*Weights[i] for i in range(N)) +
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_6564/3753500305.py:68: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   L_illiquidity*np.sum((ls[i][0]*x_1[i] + ls[i][1]*x_2[i] + ls[i][2]*x_3[i]) for i in range(N)) +
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_6564/3753500305.py:69: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   L_tc*np.sum((cs[i][0]*z_1[i] + cs[i][1]*z_2[i] + cs[i][2]*z_3[i]) for i in range(N)))
# Names[0,0] = 1.0
# Names[1,0] = 1.0
# Names[2,0] = 1.0
# Names[3,0] = 1.0
# Names[4,0] = -0.0
# Names[5,0] = 0.0
# Names[6,0] = 1.0
# Names[7,0] = 0.0
# Names[8,0] = 1.0
# Names[9,0] = 1.0
# Names[10,0] = 0.0
# Names[11,0] = 1.0
# Names[12,0] = 1.0
# Names[13,0] = -0.0
# Names[14,0] = 1.0
# Names[15,0] = 1.0
# Names[16,0] = 1.0
# Names[17,0] = 1.0
# Names[18,0] = 0.0
# Names[19,0] = 1.0
# Tickets[0,0] = 1.0
# Tickets[1,0] = 1.0
# Tickets[2,0] = 1.0
# Tickets[3,0] = 1.0
# Tickets[4,0] = 1.0
# Tickets[5,0] = 1.0
# Tickets[6,0] = 1.0
# Tickets[7,0] = 1.0
# Tickets[8,0] = 1.0
# Tickets[9,0] = 1.0
# Tickets[10,0] = 1.0
# Tickets[11,0] = 1.0
# Tickets[12,0] = 1.0
# Tickets[13,0] = 1.0
# Tickets[14,0] = 1.0
# Tickets[15,0] = 1.0
# Tickets[16,0] = 1.0
# Tickets[17,0] = 1.0
# Tickets[18,0] = 1.0
# Tickets[19,0] = 1.0
# Weigths[0,0] = 0.017673566219337588
# Weigths[1,0] = 0.02903062152370444
# Weigths[2,0] = 0.03999999999999915
# Weigths[3,0] = 0.005278154561068018
# Weigths[4,0] = 0.0
# Weigths[5,0] = 0.0
# Weigths[6,0] = 0.02304535735839327
# Weigths[7,0] = 0.0
# Weigths[8,0] = 0.19999999999998863
# Weigths[9,0] = 0.02542925162504549
# Weigths[10,0] = 0.0
# Weigths[11,0] = 0.04472754960887611
# Weigths[12,0] = 0.03999999999999915
# Weigths[13,0] = 0.0
# Weigths[14,0] = 0.03999999999999915
# Weigths[15,0] = 0.1725200458237557
# Weigths[16,0] = 0.016205894874126884
# Weigths[17,0] = 0.0400000000000027
# Weigths[18,0] = 0.0
# Weigths[19,0] = 0.30608955840570373
# Y[0,0] = 0.0
# Y[1,0] = 0.012098267123403152
# Y[2,0] = 0.04585058276947561
# Y[3,0] = 0.0
# Y[4,0] = 0.0020138655395179747
# Y[5,0] = 0.007359410586144423
# Y[6,0] = 0.012741011328318681
# Y[7,0] = 0.0053816007421742225
# Y[8,0] = 0.12615727324320186
# Y[9,0] = 0.0
# Y[10,0] = 0.008815436368555073
# Y[11,0] = 0.019838319423966678
# Y[12,0] = 0.1786759322356516
# Y[13,0] = 0.009009017515893602
# Y[14,0] = 0.03349855474658733
# Y[15,0] = 0.0050731001548054155
# Y[16,0] = 0.0
# Y[17,0] = 0.1591680548066673
# Y[18,0] = 0.012098267123403152
# Y[19,0] = 0.21896564166719984
# F[0,0] = 0.03232643378066241
# F[1,0] = 0.033583362351425866
# F[2,0] = 0.010000000000000828
# F[3,0] = 0.044721845438931984
# F[4,0] = 0.05
# F[5,0] = 0.05
# F[6,0] = 0.026954642641606713
# F[7,0] = 0.049999999999999836
# F[8,0] = 0.14999999999998864
# F[9,0] = 0.024570748374954512
# F[10,0] = 0.04999999999999982
# F[11,0] = 0.045139798471392094
# F[12,0] = 0.010000000000000828
# F[13,0] = 0.05
# F[14,0] = 0.010000000000000842
# F[15,0] = 0.12252004582375571
# F[16,0] = 0.087830480680423
# F[17,0] = 0.009999999999997275
# F[18,0] = 0.049999999999999996
# F[19,0] = 0.25608955840570374
# X[0,0] = 0.0
# X[1,0] = 0.0
# X[2,0] = 1.0
# X[3,0] = 0.0
# X[4,0] = 0.0
# X[5,0] = 0.0
# X[6,0] = 1.0
# X[7,0] = 0.0
# X[8,0] = 1.0
# X[9,0] = 1.0
# X[10,0] = 0.0
# x_1[0,0] = 0.009999999999999787
# x_1[1,0] = 0.02903062152370444
# x_1[2,0] = 0.009999999999999787
# x_1[3,0] = 0.005278154561068018
# x_1[4,0] = 0.0
# x_1[5,0] = 0.0
# x_1[6,0] = 0.010000000000000675
# x_1[7,0] = 0.0
# x_1[8,0] = 0.04999999999999716
# x_1[9,0] = 0.009999999999999787
# x_1[10,0] = 0.0
# x_1[11,0] = 0.04472754960887611
# x_1[12,0] = 0.009999999999999787
# x_1[13,0] = 0.0
# x_1[14,0] = 0.009999999999999787
# x_1[15,0] = 0.05000000000000426
# x_1[16,0] = 0.016205894874126884
# x_1[17,0] = 0.010000000000000675
# x_1[18,0] = 0.0
# x_1[19,0] = 0.19999999999998863
# x_2[0,0] = 0.007673566219337801
# x_2[1,0] = 0.0
# x_2[2,0] = 0.009999999999999787
# x_2[3,0] = 0.0
# x_2[4,0] = 0.0
# x_2[5,0] = 0.0
# x_2[6,0] = 0.010000000000000675
# x_2[7,0] = 0.0
# x_2[8,0] = 0.04999999999999716
# x_2[9,0] = 0.009999999999999787
# x_2[10,0] = 0.0
# x_2[11,0] = 0.0
# x_2[12,0] = 0.009999999999999787
# x_2[13,0] = 0.0
# x_2[14,0] = 0.009999999999999787
# x_2[15,0] = 0.05000000000000426
# x_2[16,0] = 0.0
# x_2[17,0] = 0.010000000000000675
# x_2[18,0] = 0.0
# x_2[19,0] = 0.1060895584057151
# x_3[0,0] = 0.0
# x_3[1,0] = 0.0
# x_3[2,0] = 0.019999999999999574
# x_3[3,0] = 0.0
# x_3[4,0] = 0.0
# x_3[5,0] = 0.0
# x_3[6,0] = 0.003045357358391919
# x_3[7,0] = 0.0
# x_3[8,0] = 0.09999999999999432
# x_3[9,0] = 0.005429251625045917
# x_3[10,0] = 0.0
# x_3[11,0] = 0.0
# x_3[12,0] = 0.019999999999999574
# x_3[13,0] = 0.0
# x_3[14,0] = 0.019999999999999574
# x_3[15,0] = 0.07252004582374719
# x_3[16,0] = 0.0
# x_3[17,0] = 0.02000000000000135
# x_3[18,0] = 0.0
# x_3[19,0] = 0.0
# z_1[0,0] = 0.03232643378066241
# z_1[1,0] = 0.033583362351425866
# z_1[2,0] = 0.010000000000000828
# z_1[3,0] = 0.044721845438931984
# z_1[4,0] = 0.05
# z_1[5,0] = 0.05
# z_1[6,0] = 0.026954642641606713
# z_1[7,0] = 0.04627506717542706
# z_1[8,0] = 0.14999999999998864
# z_1[9,0] = 0.024570748374954512
# z_1[10,0] = 0.04999999999999982
# z_1[11,0] = 0.045139798471392094
# z_1[12,0] = 0.010000000000000828
# z_1[13,0] = 0.016961183201097695
# z_1[14,0] = 0.010000000000000842
# z_1[15,0] = 0.06549417632717788
# z_1[16,0] = 0.087830480680423
# z_1[17,0] = 0.009999999999997275
# z_1[18,0] = 0.03210382168654118
# z_1[19,0] = 0.051217911681140725
# z_2[0,0] = 0.0
# z_2[1,0] = 0.0
# z_2[2,0] = 0.0
# z_2[3,0] = 0.0
# z_2[4,0] = 0.0
# z_2[5,0] = 0.0
# z_2[6,0] = 0.0
# z_2[7,0] = 0.0037249328245727784
# z_2[8,0] = 0.0
# z_2[9,0] = 0.0
# z_2[10,0] = 0.0
# z_2[11,0] = 0.0
# z_2[12,0] = 0.0
# z_2[13,0] = 0.033038816798902304
# z_2[14,0] = 0.0
# z_2[15,0] = 0.05702586949657783
# z_2[16,0] = 0.0
# z_2[17,0] = 0.0
# z_2[18,0] = 0.017896178313458813
# z_2[19,0] = 0.1024358233622815
# z_3[0,0] = 0.0
# z_3[1,0] = 0.0
# z_3[2,0] = 0.0
# z_3[3,0] = 0.0
# z_3[4,0] = 0.0
# z_3[5,0] = 0.0
# z_3[6,0] = 0.0
# z_3[7,0] = 0.0
# z_3[8,0] = 0.0
# z_3[9,0] = 0.0
# z_3[10,0] = 0.0
# z_3[11,0] = 0.0
# z_3[12,0] = 0.0
# z_3[13,0] = 0.0
# z_3[14,0] = 0.0
# z_3[15,0] = 0.0
# z_3[16,0] = 0.0
# z_3[17,0] = 0.0
# z_3[18,0] = 0.0
# z_3[19,0] = 0.1024358233622815
# [[0.0081147  0.0730323  0.2028675 ]
#  [0.00718499 0.06466494 0.17962484]
#  [0.00899497 0.08095475 0.22487431]
#  [0.00659752 0.05937771 0.16493807]
#  [0.00569283 0.05123543 0.14232065]
#  [0.00553745 0.04983704 0.13843621]
#  [0.01303918 0.11735262 0.32597951]
#  [0.01915005 0.17235047 0.47875129]
#  [0.01632117 0.1468905  0.40802917]
#  [0.00790336 0.07113023 0.19758397]
#  [0.0059904  0.05391364 0.14976012]
#  [0.00946555 0.08518999 0.23663886]
#  [0.00726196 0.06535768 0.18154912]
#  [0.00479967 0.04319706 0.11999183]
#  [0.00383303 0.03449723 0.09582563]
#  [0.01823737 0.16413632 0.45593423]
#  [0.00462158 0.04159423 0.11553953]
#  [0.00844773 0.07602958 0.21119328]
#  [0.01161996 0.10457968 0.29049911]
#  [0.01392878 0.12535899 0.34821942]]
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 231 columns and 602 nonzeros
# Model fingerprint: 0x7fb08f15
# Variable types: 191 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-08, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-03, 1e+00]
# Found heuristic solution: objective 29.1743855
# Presolve removed 199 rows and 79 columns
# Presolve time: 0.00s
# Presolved: 104 rows, 152 columns, 331 nonzeros
# Found heuristic solution: objective 29.1743609
# Variable types: 123 continuous, 29 integer (29 binary)
#
# Root relaxation: objective 1.079182e+00, 85 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.07918    0    9   29.17436    1.07918  96.3%     -    0s
# H    0     0                       1.4994454    1.07918  28.0%     -    0s
# H    0     0                       1.4988333    1.07918  28.0%     -    0s
# H    0     0                       1.4312744    1.07918  24.6%     -    0s
# H    0     0                       1.3984624    1.38427  1.02%     -    0s
#      0     0    1.39177    0    2    1.39846    1.39177  0.48%     -    0s
# *    0     0               0       1.3936170    1.39362  0.00%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 1
#   Implied bound: 9
#   MIR: 4
#   Flow cover: 11
#   Relax-and-lift: 1
#
# Explored 1 nodes (119 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1.39362 1.43127 1.49883 ... 29.1744
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.393617041659e+00, best bound 1.393617041659e+00, gap 0.0000%
# Names[0,0] = 1.0
# Names[1,0] = 1.0
# Names[2,0] = 0.0
# Names[3,0] = 1.0
# Names[4,0] = -0.0
# Names[5,0] = 0.0
# Names[6,0] = 1.0
# Names[7,0] = 0.0
# Names[8,0] = 1.0
# Names[9,0] = 1.0
# Names[10,0] = 0.0
# Names[11,0] = 1.0
# Names[12,0] = 0.0
# Names[13,0] = -0.0
# Names[14,0] = 0.0
# Names[15,0] = 1.0
# Names[16,0] = 1.0
# Names[17,0] = 0.0
# Names[18,0] = 0.0
# Names[19,0] = 1.0
# Tickets[0,0] = 1.0
# Tickets[1,0] = 1.0
# Tickets[2,0] = -0.0
# Tickets[3,0] = 1.0
# Tickets[4,0] = 0.0
# Tickets[5,0] = 0.0
# Tickets[6,0] = 1.0
# Tickets[7,0] = -0.0
# Tickets[8,0] = 1.0
# Tickets[9,0] = 1.0
# Tickets[10,0] = 0.0
# Tickets[11,0] = 1.0
# Tickets[12,0] = -0.0
# Tickets[13,0] = 0.0
# Tickets[14,0] = -0.0
# Tickets[15,0] = 1.0
# Tickets[16,0] = 1.0
# Tickets[17,0] = -0.0
# Tickets[18,0] = 0.0
# Tickets[19,0] = 1.0
# Weigths[0,0] = 0.017416576118712026
# Weigths[1,0] = 0.03129371204491923
# Weigths[2,0] = 0.0
# Weigths[3,0] = 0.005535720914653256
# Weigths[4,0] = 0.0
# Weigths[5,0] = 0.0
# Weigths[6,0] = 0.02195978668894083
# Weigths[7,0] = 0.0
# Weigths[8,0] = 0.07042976711115592
# Weigths[9,0] = 0.022548178223949642
# Weigths[10,0] = 0.0
# Weigths[11,0] = 0.044547790160049144
# Weigths[12,0] = 0.0
# Weigths[13,0] = 0.0
# Weigths[14,0] = 0.0
# Weigths[15,0] = 0.186948768218504
# Weigths[16,0] = 0.013933775483652999
# Weigths[17,0] = 0.0
# Weigths[18,0] = 0.0
# Weigths[19,0] = 0.5853859250354628
# Y[0,0] = 0.0
# Y[1,0] = 0.013568901127295536
# Y[2,0] = 0.08149825727460458
# Y[3,0] = 0.0
# Y[4,0] = 0.002569661593341712
# Y[5,0] = 0.007035084163168949
# Y[6,0] = 0.01280709997612459
# Y[7,0] = 0.0057720158129554765
# Y[8,0] = 0.0
# Y[9,0] = 0.0
# Y[10,0] = 0.0083488291723679
# Y[11,0] = 0.02010293370251771
# Y[12,0] = 0.20472170512359034
# Y[13,0] = 0.009184442936808054
# Y[14,0] = 0.006165512593288508
# Y[15,0] = 0.0
# Y[16,0] = 0.0
# Y[17,0] = 0.18998459139066914
# Y[18,0] = 0.013568901127295524
# Y[19,0] = 0.4823700663821523
# F[0,0] = 0.017416576118712026
# F[1,0] = 0.03129371204491923
# F[2,0] = 0.0
# F[3,0] = 0.005535720914653256
# F[4,0] = 0.0
# F[5,0] = 0.0
# F[6,0] = 0.02195978668894083
# F[7,0] = 0.0
# F[8,0] = 0.07042976711115592
# F[9,0] = 0.022548178223949642
# F[10,0] = 0.0
# F[11,0] = 0.044547790160049144
# F[12,0] = 0.0
# F[13,0] = 0.0
# F[14,0] = 0.0
# F[15,0] = 0.186948768218504
# F[16,0] = 0.013933775483652999
# F[17,0] = 0.0
# F[18,0] = 0.0
# F[19,0] = 0.5853859250354628
# X[0,0] = 0.0
# X[1,0] = 0.0
# X[2,0] = 1.0
# X[3,0] = 0.0
# X[4,0] = 0.0
# X[5,0] = 0.0
# X[6,0] = 1.0
# X[7,0] = 0.0
# X[8,0] = 1.0
# X[9,0] = 1.0
# X[10,0] = 0.0
# x_1[0,0] = 0.009999999999999787
# x_1[1,0] = 0.03129371204491923
# x_1[2,0] = 0.0
# x_1[3,0] = 0.005535720914653256
# x_1[4,0] = 0.0
# x_1[5,0] = 0.0
# x_1[6,0] = 0.010000000000000675
# x_1[7,0] = 0.0
# x_1[8,0] = 0.04999999999999715
# x_1[9,0] = 0.009999999999999787
# x_1[10,0] = 0.0
# x_1[11,0] = 0.044547790160049144
# x_1[12,0] = 0.0
# x_1[13,0] = 0.0
# x_1[14,0] = 0.0
# x_1[15,0] = 0.05000000000000426
# x_1[16,0] = 0.013933775483652999
# x_1[17,0] = 0.0
# x_1[18,0] = 0.0
# x_1[19,0] = 0.19999999999998863
# x_2[0,0] = 0.007416576118712239
# x_2[1,0] = 0.0
# x_2[2,0] = 0.0
# x_2[3,0] = 0.0
# x_2[4,0] = 0.0
# x_2[5,0] = 0.0
# x_2[6,0] = 0.010000000000000675
# x_2[7,0] = 0.0
# x_2[8,0] = 0.020429767111158764
# x_2[9,0] = 0.009999999999999787
# x_2[10,0] = 0.0
# x_2[11,0] = 0.0
# x_2[12,0] = 0.0
# x_2[13,0] = 0.0
# x_2[14,0] = 0.0
# x_2[15,0] = 0.05000000000000426
# x_2[16,0] = 0.0
# x_2[17,0] = 0.0
# x_2[18,0] = 0.0
# x_2[19,0] = 0.19999999999998863
# x_3[0,0] = 0.0
# x_3[1,0] = 0.0
# x_3[2,0] = 0.0
# x_3[3,0] = 0.0
# x_3[4,0] = 0.0
# x_3[5,0] = 0.0
# x_3[6,0] = 0.00195978668893948
# x_3[7,0] = 0.0
# x_3[8,0] = 0.0
# x_3[9,0] = 0.0025481782239500685
# x_3[10,0] = 0.0
# x_3[11,0] = 0.0
# x_3[12,0] = 0.0
# x_3[13,0] = 0.0
# x_3[14,0] = 0.0
# x_3[15,0] = 0.08694876821849548
# x_3[16,0] = 0.0
# x_3[17,0] = 0.0
# x_3[18,0] = 0.0
# x_3[19,0] = 0.18538592503548557
# z_1[0,0] = 0.017416576118712026
# z_1[1,0] = 0.03129371204491923
# z_1[2,0] = 0.0
# z_1[3,0] = 0.005535720914653256
# z_1[4,0] = 0.0
# z_1[5,0] = 0.0
# z_1[6,0] = 0.02195978668894083
# z_1[7,0] = 0.0
# z_1[8,0] = 0.07042976711115592
# z_1[9,0] = 0.022548178223949642
# z_1[10,0] = 0.0
# z_1[11,0] = 0.044547790160049144
# z_1[12,0] = 0.0
# z_1[13,0] = 0.0
# z_1[14,0] = 0.0
# z_1[15,0] = 0.13504580368849986
# z_1[16,0] = 0.013933775483652999
# z_1[17,0] = 0.0
# z_1[18,0] = 0.0
# z_1[19,0] = 0.11802023940914226
# z_2[0,0] = 0.0
# z_2[1,0] = 0.0
# z_2[2,0] = 0.0
# z_2[3,0] = 0.0
# z_2[4,0] = 0.0
# z_2[5,0] = 0.0
# z_2[6,0] = 0.0
# z_2[7,0] = 0.0
# z_2[8,0] = 0.0
# z_2[9,0] = 0.0
# z_2[10,0] = 0.0
# z_2[11,0] = 0.0
# z_2[12,0] = 0.0
# z_2[13,0] = 0.0
# z_2[14,0] = 0.0
# z_2[15,0] = 0.05190296453000415
# z_2[16,0] = 0.0
# z_2[17,0] = 0.0
# z_2[18,0] = 0.0
# z_2[19,0] = 0.23604047881828452
# z_3[0,0] = 0.0
# z_3[1,0] = 0.0
# z_3[2,0] = 0.0
# z_3[3,0] = 0.0
# z_3[4,0] = 0.0
# z_3[5,0] = 0.0
# z_3[6,0] = 0.0
# z_3[7,0] = 0.0
# z_3[8,0] = 0.0
# z_3[9,0] = 0.0
# z_3[10,0] = 0.0
# z_3[11,0] = 0.0
# z_3[12,0] = 0.0
# z_3[13,0] = 0.0
# z_3[14,0] = 0.0
# z_3[15,0] = 0.0
# z_3[16,0] = 0.0
# z_3[17,0] = 0.0
# z_3[18,0] = 0.0
# z_3[19,0] = 0.23132520680803603
# [[0.00670926 0.06038336 0.16773155]
#  [0.00739208 0.06652868 0.1848019 ]
#  [0.01171485 0.10543364 0.29287123]
#  [0.00777758 0.06999824 0.19443956]
#  [0.00138389 0.01245498 0.03459717]
#  [0.00726065 0.06534588 0.18151632]
#  [0.00774223 0.06968008 0.19355577]
#  [0.00349726 0.03147532 0.08743144]
#  [0.00524664 0.04721972 0.13116588]
#  [0.00435225 0.03917029 0.10880635]
#  [0.01038114 0.09343029 0.25952857]
#  [0.01459989 0.13139902 0.36499727]
#  [0.00447225 0.04025029 0.11180636]
#  [0.00482475 0.04342276 0.12061878]
#  [0.00259798 0.02338181 0.06494948]
#  [0.00774677 0.06972089 0.19366915]
#  [0.00280888 0.02527993 0.07022202]
#  [0.00520944 0.04688492 0.13023588]
#  [0.00474265 0.04268382 0.11856617]
#  [0.0052728  0.04745524 0.13182012]]
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 231 columns and 602 nonzeros
# Model fingerprint: 0x25acf285
# Variable types: 191 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-08, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-03, 1e+00]
# Presolve removed 166 rows and 43 columns
# Presolve time: 0.00s
# Presolved: 137 rows, 188 columns, 429 nonzeros
# Variable types: 151 continuous, 37 integer (37 binary)
# Found heuristic solution: objective 2.7251365
#
# Root relaxation: objective 1.886209e+00, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.88621    0    7    2.72514    1.88621  30.8%     -    0s
# H    0     0                       2.2474311    1.88621  16.1%     -    0s
# H    0     0                       2.0908804    1.88621  9.79%     -    0s
#      0     0    2.02913    0    5    2.09088    2.02913  2.95%     -    0s
# H    0     0                       2.0724407    2.02913  2.09%     -    0s
#      0     0    2.06409    0    5    2.07244    2.06409  0.40%     -    0s
#      0     0    2.06489    0    2    2.07244    2.06489  0.36%     -    0s
#      0     0     cutoff    0         2.07244    2.07244  0.00%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 2
#   Implied bound: 5
#   Clique: 1
#   MIR: 1
#   Flow cover: 12
#   Flow path: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (141 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2.07244 2.09088 2.24743 2.72514
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.072440691222e+00, best bound 2.072440691222e+00, gap 0.0000%
# Names[0,0] = 1.0
# Names[1,0] = 1.0
# Names[2,0] = 0.0
# Names[3,0] = 1.0
# Names[4,0] = 0.0
# Names[5,0] = 0.0
# Names[6,0] = 1.0
# Names[7,0] = 0.0
# Names[8,0] = 1.0
# Names[9,0] = 1.0
# Names[10,0] = 0.0
# Names[11,0] = 1.0
# Names[12,0] = 0.0
# Names[13,0] = 0.0
# Names[14,0] = 0.0
# Names[15,0] = 1.0
# Names[16,0] = 1.0
# Names[17,0] = 0.0
# Names[18,0] = 0.0
# Names[19,0] = 1.0
# Tickets[0,0] = 1.0
# Tickets[1,0] = 1.0
# Tickets[2,0] = 1.0
# Tickets[3,0] = 1.0
# Tickets[4,0] = 0.0
# Tickets[5,0] = 0.0
# Tickets[6,0] = 1.0
# Tickets[7,0] = 0.0
# Tickets[8,0] = 0.0
# Tickets[9,0] = 1.0
# Tickets[10,0] = 0.0
# Tickets[11,0] = 1.0
# Tickets[12,0] = 1.0
# Tickets[13,0] = 0.0
# Tickets[14,0] = 1.0
# Tickets[15,0] = 1.0
# Tickets[16,0] = 1.0
# Tickets[17,0] = 1.0
# Tickets[18,0] = 0.0
# Tickets[19,0] = 1.0
# Weigths[0,0] = 0.01657823335008935
# Weigths[1,0] = 0.030964152564242845
# Weigths[2,0] = 0.0
# Weigths[3,0] = 0.00514252008099394
# Weigths[4,0] = 0.0
# Weigths[5,0] = 0.0
# Weigths[6,0] = 0.020593292471285742
# Weigths[7,0] = 0.0
# Weigths[8,0] = 0.19999999999998863
# Weigths[9,0] = 0.022463409682746738
# Weigths[10,0] = 0.0
# Weigths[11,0] = 0.04052305980189783
# Weigths[12,0] = 0.0
# Weigths[13,0] = 0.0
# Weigths[14,0] = 0.0
# Weigths[15,0] = 0.20000000000001705
# Weigths[16,0] = 0.014106764227381547
# Weigths[17,0] = 0.0
# Weigths[18,0] = 0.0
# Weigths[19,0] = 0.4496285678213563
# Y[0,0] = 0.0
# Y[1,0] = 0.012939081815069274
# Y[2,0] = 0.08488045108054676
# Y[3,0] = 0.0
# Y[4,0] = 0.0026805892992664685
# Y[5,0] = 0.006621177296940293
# Y[6,0] = 0.012210985627935728
# Y[7,0] = 0.00558980833099537
# Y[8,0] = 0.12670408644763112
# Y[9,0] = 0.0
# Y[10,0] = 0.0071387051216575785
# Y[11,0] = 0.01826150393717183
# Y[12,0] = 0.2056289356495027
# Y[13,0] = 0.008442209516247728
# Y[14,0] = 0.005838533944646885
# Y[15,0] = 0.016598434524239702
# Y[16,0] = 0.0
# Y[17,0] = 0.19572582960586618
# Y[18,0] = 0.01293908181506927
# Y[19,0] = 0.34877122930869153
# F[0,0] = 0.0010953328692482368
# F[1,0] = 0.0019335310405384117
# F[2,0] = 0.03999999999999915
# F[3,0] = 0.00013563448007407764
# F[4,0] = 0.0
# F[5,0] = 0.0
# F[6,0] = 0.0024520648871075267
# F[7,0] = 0.0
# F[8,0] = 0.0
# F[9,0] = 0.0029658419422987532
# F[10,0] = 0.0
# F[11,0] = 0.0042044898069782816
# F[12,0] = 0.03999999999999915
# F[13,0] = 0.0
# F[14,0] = 0.03999999999999915
# F[15,0] = 0.02747995417626134
# F[16,0] = 0.0020991306467453372
# F[17,0] = 0.0400000000000027
# F[18,0] = 0.0
# F[19,0] = 0.14353900941565256
# X[0,0] = 0.0
# X[1,0] = 0.0
# X[2,0] = 1.0
# X[3,0] = 0.0
# X[4,0] = 0.0
# X[5,0] = 0.0
# X[6,0] = 1.0
# X[7,0] = 0.0
# X[8,0] = 1.0
# X[9,0] = 1.0
# X[10,0] = 0.0
# x_1[0,0] = 0.009999999999999787
# x_1[1,0] = 0.030964152564242845
# x_1[2,0] = 0.0
# x_1[3,0] = 0.00514252008099394
# x_1[4,0] = 0.0
# x_1[5,0] = 0.0
# x_1[6,0] = 0.010000000000000675
# x_1[7,0] = 0.0
# x_1[8,0] = 0.04999999999999716
# x_1[9,0] = 0.009999999999999787
# x_1[10,0] = 0.0
# x_1[11,0] = 0.040523059801897826
# x_1[12,0] = 0.0
# x_1[13,0] = 0.0
# x_1[14,0] = 0.0
# x_1[15,0] = 0.05000000000000426
# x_1[16,0] = 0.014106764227381547
# x_1[17,0] = 0.0
# x_1[18,0] = 0.0
# x_1[19,0] = 0.19999999999998863
# x_2[0,0] = 0.006578233350089564
# x_2[1,0] = 0.0
# x_2[2,0] = 0.0
# x_2[3,0] = 0.0
# x_2[4,0] = 0.0
# x_2[5,0] = 0.0
# x_2[6,0] = 0.010000000000000675
# x_2[7,0] = 0.0
# x_2[8,0] = 0.04999999999999716
# x_2[9,0] = 0.009999999999999787
# x_2[10,0] = 0.0
# x_2[11,0] = 0.0
# x_2[12,0] = 0.0
# x_2[13,0] = 0.0
# x_2[14,0] = 0.0
# x_2[15,0] = 0.05000000000000426
# x_2[16,0] = 0.0
# x_2[17,0] = 0.0
# x_2[18,0] = 0.0
# x_2[19,0] = 0.19999999999998863
# x_3[0,0] = 0.0
# x_3[1,0] = 0.0
# x_3[2,0] = 0.0
# x_3[3,0] = 0.0
# x_3[4,0] = 0.0
# x_3[5,0] = 0.0
# x_3[6,0] = 0.0005932924712843922
# x_3[7,0] = 0.0
# x_3[8,0] = 0.09999999999999432
# x_3[9,0] = 0.002463409682747164
# x_3[10,0] = 0.0
# x_3[11,0] = 0.0
# x_3[12,0] = 0.0
# x_3[13,0] = 0.0
# x_3[14,0] = 0.0
# x_3[15,0] = 0.10000000000000853
# x_3[16,0] = 0.0
# x_3[17,0] = 0.0
# x_3[18,0] = 0.0
# x_3[19,0] = 0.04962856782137903
# z_1[0,0] = 0.0010953328692482368
# z_1[1,0] = 0.0019335310405384117
# z_1[2,0] = 0.03999999999999915
# z_1[3,0] = 0.00013563448007407764
# z_1[4,0] = 0.0
# z_1[5,0] = 0.0
# z_1[6,0] = 0.0024520648871075267
# z_1[7,0] = 0.0
# z_1[8,0] = 0.0
# z_1[9,0] = 0.0029658419422987532
# z_1[10,0] = 0.0
# z_1[11,0] = 0.0042044898069782816
# z_1[12,0] = 0.03999999999999915
# z_1[13,0] = 0.0
# z_1[14,0] = 0.03999999999999915
# z_1[15,0] = 0.02747995417626134
# z_1[16,0] = 0.0020991306467453372
# z_1[17,0] = 0.0400000000000027
# z_1[18,0] = 0.0
# z_1[19,0] = 0.07261408008399177
# z_2[0,0] = 0.0
# z_2[1,0] = 0.0
# z_2[2,0] = 0.0
# z_2[3,0] = 0.0
# z_2[4,0] = 0.0
# z_2[5,0] = 0.0
# z_2[6,0] = 0.0
# z_2[7,0] = 0.0
# z_2[8,0] = 0.0
# z_2[9,0] = 0.0
# z_2[10,0] = 0.0
# z_2[11,0] = 0.0
# z_2[12,0] = 0.0
# z_2[13,0] = 0.0
# z_2[14,0] = 0.0
# z_2[15,0] = 0.0
# z_2[16,0] = 0.0
# z_2[17,0] = 0.0
# z_2[18,0] = 0.0
# z_2[19,0] = 0.0709249293316608
# z_3[0,0] = 0.0
# z_3[1,0] = 0.0
# z_3[2,0] = 0.0
# z_3[3,0] = 0.0
# z_3[4,0] = 0.0
# z_3[5,0] = 0.0
# z_3[6,0] = 0.0
# z_3[7,0] = 0.0
# z_3[8,0] = 0.0
# z_3[9,0] = 0.0
# z_3[10,0] = 0.0
# z_3[11,0] = 0.0
# z_3[12,0] = 0.0
# z_3[13,0] = 0.0
# z_3[14,0] = 0.0
# z_3[15,0] = 0.0
# z_3[16,0] = 0.0
# z_3[17,0] = 0.0
# z_3[18,0] = 0.0
# z_3[19,0] = 0.0
# [[0.01048281 0.09434532 0.26207033]
#  [0.00761295 0.06851654 0.19032372]
#  [0.01272257 0.11450317 0.31806436]
#  [0.02558809 0.2302928  0.63970223]
#  [0.01213619 0.10922575 0.30340487]
#  [0.02074784 0.18673059 0.51869609]
#  [0.03353988 0.30185894 0.83849706]
#  [0.01038625 0.09347626 0.25965628]
#  [0.01588882 0.14299935 0.39722043]
#  [0.01562393 0.14061534 0.39059817]
#  [0.03524436 0.31719922 0.88110894]
#  [0.0089312  0.08038076 0.2232799 ]
#  [0.01079042 0.09711378 0.26976051]
#  [0.01068745 0.09618703 0.26718619]
#  [0.00720265 0.06482389 0.18006636]
#  [0.01474745 0.13272702 0.36868616]
#  [0.01129628 0.10166653 0.28240702]
#  [0.00611093 0.05499834 0.15277316]
#  [0.01443059 0.12987534 0.36076484]
#  [0.02038941 0.18350472 0.50973532]]
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 231 columns and 602 nonzeros
# Model fingerprint: 0x6ccd7491
# Variable types: 191 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-08, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-03, 1e+00]
# Found heuristic solution: objective 30.0017785
# Presolve removed 173 rows and 53 columns
# Presolve time: 0.00s
# Presolved: 130 rows, 178 columns, 411 nonzeros
# Found heuristic solution: objective 30.0017784
# Variable types: 146 continuous, 32 integer (32 binary)
#
# Root relaxation: objective 1.516706e+00, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.51671    0    9   30.00178    1.51671  94.9%     -    0s
# H    0     0                       1.7821795    1.51671  14.9%     -    0s
# H    0     0                       1.7714522    1.51671  14.4%     -    0s
# H    0     0                       1.7424826    1.51671  13.0%     -    0s
# H    0     0                       1.7339981    1.51671  12.5%     -    0s
# H    0     0                       1.7189670    1.62103  5.70%     -    0s
# H    0     0                       1.7116338    1.62103  5.29%     -    0s
#      0     0    1.62103    0    5    1.71163    1.62103  5.29%     -    0s
# H    0     0                       1.6986957    1.62103  4.57%     -    0s
# H    0     0                       1.6986026    1.69653  0.12%     -    0s
#      0     0    1.69820    0    3    1.69860    1.69820  0.02%     -    0s
#      0     0          -    0         1.69860    1.69846  0.01%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 5
#   Implied bound: 6
#   MIR: 2
#   Flow cover: 6
#   Flow path: 2
#   Relax-and-lift: 3
#
# Explored 1 nodes (131 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1.6986 1.6987 1.71897 ... 30.0018
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.698602615569e+00, best bound 1.698456431939e+00, gap 0.0086%
# Names[0,0] = 1.0
# Names[1,0] = 1.0
# Names[2,0] = 0.0
# Names[3,0] = 1.0
# Names[4,0] = 0.0
# Names[5,0] = 0.0
# Names[6,0] = 1.0
# Names[7,0] = 0.0
# Names[8,0] = 1.0
# Names[9,0] = 1.0
# Names[10,0] = 0.0
# Names[11,0] = 1.0
# Names[12,0] = -0.0
# Names[13,0] = -0.0
# Names[14,0] = 0.0
# Names[15,0] = 1.0
# Names[16,0] = 1.0
# Names[17,0] = -0.0
# Names[18,0] = 0.0
# Names[19,0] = 1.0
# Tickets[0,0] = 1.0
# Tickets[1,0] = 1.0
# Tickets[2,0] = -0.0
# Tickets[3,0] = 1.0
# Tickets[4,0] = -0.0
# Tickets[5,0] = 0.0
# Tickets[6,0] = 1.0
# Tickets[7,0] = -0.0
# Tickets[8,0] = 1.0
# Tickets[9,0] = 1.0
# Tickets[10,0] = -0.0
# Tickets[11,0] = 1.0
# Tickets[12,0] = 0.0
# Tickets[13,0] = 0.0
# Tickets[14,0] = -0.0
# Tickets[15,0] = 1.0
# Tickets[16,0] = 1.0
# Tickets[17,0] = 0.0
# Tickets[18,0] = -0.0
# Tickets[19,0] = 1.0
# Weigths[0,0] = 0.016886027115028738
# Weigths[1,0] = 0.03390721126904729
# Weigths[2,0] = 0.0
# Weigths[3,0] = 0.005234926211013463
# Weigths[4,0] = 0.0
# Weigths[5,0] = 0.0
# Weigths[6,0] = 0.021622373208545834
# Weigths[7,0] = 0.0
# Weigths[8,0] = 0.07973943492631053
# Weigths[9,0] = 0.02282204684455976
# Weigths[10,0] = 0.0
# Weigths[11,0] = 0.03713949457373531
# Weigths[12,0] = 0.0
# Weigths[13,0] = 0.0
# Weigths[14,0] = 0.0
# Weigths[15,0] = 0.17649543881070104
# Weigths[16,0] = 0.015659798126961704
# Weigths[17,0] = 0.0
# Weigths[18,0] = 0.0
# Weigths[19,0] = 0.5904932489140962
# Y[0,0] = 0.0
# Y[1,0] = 0.015197587652105368
# Y[2,0] = 0.08039679771830426
# Y[3,0] = 0.0
# Y[4,0] = 0.0031444849077890934
# Y[5,0] = 0.0068454572281311556
# Y[6,0] = 0.013314481745837294
# Y[7,0] = 0.006469024517705868
# Y[8,0] = 0.0
# Y[9,0] = 0.0
# Y[10,0] = 0.006643686508761612
# Y[11,0] = 0.016660067037226584
# Y[12,0] = 0.20740162499592055
# Y[13,0] = 0.006871895620675848
# Y[14,0] = 0.006167707639006173
# Y[15,0] = 0.0
# Y[16,0] = 0.0
# Y[17,0] = 0.18792094985768648
# Y[18,0] = 0.015197587652105372
# Y[19,0] = 0.4818870802109174
# F[0,0] = 0.000530549003683288
# F[1,0] = 0.0026134992241280616
# F[2,0] = 0.0
# F[3,0] = 0.0003007947036397932
# F[4,0] = 0.0
# F[5,0] = 0.0
# F[6,0] = 0.0003374134803949963
# F[7,0] = 0.0
# F[8,0] = 0.009309667815154604
# F[9,0] = 0.00027386862061012235
# F[10,0] = 0.0
# F[11,0] = 0.007408295586313833
# F[12,0] = 0.0
# F[13,0] = 0.0
# F[14,0] = 0.0
# F[15,0] = 0.01045332940780297
# F[16,0] = 0.0017260226433087056
# F[17,0] = 0.0
# F[18,0] = 0.0
# F[19,0] = 0.00510732387863333
# X[0,0] = 0.0
# X[1,0] = 0.0
# X[2,0] = 1.0
# X[3,0] = 0.0
# X[4,0] = 0.0
# X[5,0] = 0.0
# X[6,0] = 1.0
# X[7,0] = 0.0
# X[8,0] = 1.0
# X[9,0] = 1.0
# X[10,0] = 0.0
# x_1[0,0] = 0.009999999999999787
# x_1[1,0] = 0.03390721126904729
# x_1[2,0] = 0.0
# x_1[3,0] = 0.005234926211013463
# x_1[4,0] = 0.0
# x_1[5,0] = 0.0
# x_1[6,0] = 0.010000000000000675
# x_1[7,0] = 0.0
# x_1[8,0] = 0.04999999999999716
# x_1[9,0] = 0.009999999999999787
# x_1[10,0] = 0.0
# x_1[11,0] = 0.03713949457373531
# x_1[12,0] = 0.0
# x_1[13,0] = 0.0
# x_1[14,0] = 0.0
# x_1[15,0] = 0.05000000000000426
# x_1[16,0] = 0.015659798126961704
# x_1[17,0] = 0.0
# x_1[18,0] = 0.0
# x_1[19,0] = 0.19999999999998863
# x_2[0,0] = 0.006886027115028951
# x_2[1,0] = 0.0
# x_2[2,0] = 0.0
# x_2[3,0] = 0.0
# x_2[4,0] = 0.0
# x_2[5,0] = 0.0
# x_2[6,0] = 0.010000000000000675
# x_2[7,0] = 0.0
# x_2[8,0] = 0.02973943492631337
# x_2[9,0] = 0.009999999999999787
# x_2[10,0] = 0.0
# x_2[11,0] = 0.0
# x_2[12,0] = 0.0
# x_2[13,0] = 0.0
# x_2[14,0] = 0.0
# x_2[15,0] = 0.05000000000000426
# x_2[16,0] = 0.0
# x_2[17,0] = 0.0
# x_2[18,0] = 0.0
# x_2[19,0] = 0.19999999999998863
# x_3[0,0] = 0.0
# x_3[1,0] = 0.0
# x_3[2,0] = 0.0
# x_3[3,0] = 0.0
# x_3[4,0] = 0.0
# x_3[5,0] = 0.0
# x_3[6,0] = 0.0016223732085444836
# x_3[7,0] = 0.0
# x_3[8,0] = 0.0
# x_3[9,0] = 0.0028220468445601873
# x_3[10,0] = 0.0
# x_3[11,0] = 0.0
# x_3[12,0] = 0.0
# x_3[13,0] = 0.0
# x_3[14,0] = 0.0
# x_3[15,0] = 0.07649543881069251
# x_3[16,0] = 0.0
# x_3[17,0] = 0.0
# x_3[18,0] = 0.0
# x_3[19,0] = 0.1904932489141189
# z_1[0,0] = 0.000530549003683288
# z_1[1,0] = 0.0026134992241280616
# z_1[2,0] = 0.0
# z_1[3,0] = 0.0003007947036397932
# z_1[4,0] = 0.0
# z_1[5,0] = 0.0
# z_1[6,0] = 0.0003374134803949963
# z_1[7,0] = 0.0
# z_1[8,0] = 0.009309667815154604
# z_1[9,0] = 0.00027386862061012235
# z_1[10,0] = 0.0
# z_1[11,0] = 0.007408295586313833
# z_1[12,0] = 0.0
# z_1[13,0] = 0.0
# z_1[14,0] = 0.0
# z_1[15,0] = 0.01045332940780297
# z_1[16,0] = 0.0017260226433087056
# z_1[17,0] = 0.0
# z_1[18,0] = 0.0
# z_1[19,0] = 0.00510732387863333
# z_2[0,0] = 0.0
# z_2[1,0] = 0.0
# z_2[2,0] = 0.0
# z_2[3,0] = 0.0
# z_2[4,0] = 0.0
# z_2[5,0] = 0.0
# z_2[6,0] = 0.0
# z_2[7,0] = 0.0
# z_2[8,0] = 0.0
# z_2[9,0] = 0.0
# z_2[10,0] = 0.0
# z_2[11,0] = 0.0
# z_2[12,0] = 0.0
# z_2[13,0] = 0.0
# z_2[14,0] = 0.0
# z_2[15,0] = 0.0
# z_2[16,0] = 0.0
# z_2[17,0] = 0.0
# z_2[18,0] = 0.0
# z_2[19,0] = 0.0
# z_3[0,0] = 0.0
# z_3[1,0] = 0.0
# z_3[2,0] = 0.0
# z_3[3,0] = 0.0
# z_3[4,0] = 0.0
# z_3[5,0] = 0.0
# z_3[6,0] = 0.0
# z_3[7,0] = 0.0
# z_3[8,0] = 0.0
# z_3[9,0] = 0.0
# z_3[10,0] = 0.0
# z_3[11,0] = 0.0
# z_3[12,0] = 0.0
# z_3[13,0] = 0.0
# z_3[14,0] = 0.0
# z_3[15,0] = 0.0
# z_3[16,0] = 0.0
# z_3[17,0] = 0.0
# z_3[18,0] = 0.0
# z_3[19,0] = 0.0
# [[0.01454139 0.13087253 0.36353481]
#  [0.00452964 0.04076679 0.1132411 ]
#  [0.0422879  0.38059114 1.0571976 ]
#  [0.01951478 0.17563306 0.4878696 ]
#  [0.0053559  0.04820307 0.1338974 ]
#  [0.0248865  0.22397853 0.62216259]
#  [0.01993396 0.17940565 0.49834903]
#  [0.00679688 0.06117191 0.16992196]
#  [0.01735207 0.15616866 0.43380182]
#  [0.02061069 0.18549618 0.51526716]
#  [0.03346643 0.3011979  0.83666084]
#  [0.01959885 0.17638969 0.48997137]
#  [0.01857806 0.16720257 0.46445157]
#  [0.03657713 0.32919416 0.91442821]
#  [0.04815859 0.43342732 1.20396478]
#  [0.02488146 0.2239331  0.6220364 ]
#  [0.01276565 0.11489084 0.31914123]
#  [0.02243044 0.20187392 0.56076089]
#  [0.01445512 0.13009606 0.36137795]
#  [0.01110928 0.09998348 0.2777319 ]]
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 231 columns and 602 nonzeros
# Model fingerprint: 0xac074396
# Variable types: 191 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-08, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-03, 1e+00]
# Found heuristic solution: objective 16.4894973
# Presolve removed 177 rows and 56 columns
# Presolve time: 0.00s
# Presolved: 126 rows, 175 columns, 403 nonzeros
# Found heuristic solution: objective 16.4894777
# Variable types: 143 continuous, 32 integer (32 binary)
#
# Root relaxation: objective 1.278921e+00, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.27892    0    8   16.48948    1.27892  92.2%     -    0s
# H    0     0                       1.5465677    1.27892  17.3%     -    0s
# H    0     0                       1.5382208    1.38833  9.74%     -    0s
# H    0     0                       1.5105948    1.38833  8.09%     -    0s
#      0     0    1.38833    0    5    1.51059    1.38833  8.09%     -    0s
# H    0     0                       1.4799158    1.38833  6.19%     -    0s
# H    0     0                       1.4791828    1.38833  6.14%     -    0s
#      0     0    1.46457    0    2    1.47918    1.46457  0.99%     -    0s
# H    0     0                       1.4788187    1.46457  0.96%     -    0s
# H    0     0                       1.4741580    1.46457  0.65%     -    0s
# H    0     0                       1.4645918    1.46457  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 2
#   Implied bound: 3
#   MIR: 2
#   Flow cover: 5
#   Relax-and-lift: 3
#
# Explored 1 nodes (124 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1.46459 1.47416 1.47882 ... 16.4895
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.464591845908e+00, best bound 1.464581862234e+00, gap 0.0007%
# Names[0,0] = 1.0
# Names[1,0] = 1.0
# Names[2,0] = -0.0
# Names[3,0] = 1.0
# Names[4,0] = 0.0
# Names[5,0] = 0.0
# Names[6,0] = 1.0
# Names[7,0] = 0.0
# Names[8,0] = 1.0
# Names[9,0] = 1.0
# Names[10,0] = 0.0
# Names[11,0] = 1.0
# Names[12,0] = -0.0
# Names[13,0] = 0.0
# Names[14,0] = -0.0
# Names[15,0] = 1.0
# Names[16,0] = 1.0
# Names[17,0] = -0.0
# Names[18,0] = 0.0
# Names[19,0] = 1.0
# Tickets[0,0] = 1.0
# Tickets[1,0] = 1.0
# Tickets[2,0] = 0.0
# Tickets[3,0] = 1.0
# Tickets[4,0] = -0.0
# Tickets[5,0] = 0.0
# Tickets[6,0] = 1.0
# Tickets[7,0] = 0.0
# Tickets[8,0] = 1.0
# Tickets[9,0] = 1.0
# Tickets[10,0] = -0.0
# Tickets[11,0] = 1.0
# Tickets[12,0] = 0.0
# Tickets[13,0] = -0.0
# Tickets[14,0] = 0.0
# Tickets[15,0] = 1.0
# Tickets[16,0] = 1.0
# Tickets[17,0] = 0.0
# Tickets[18,0] = -0.0
# Tickets[19,0] = 1.0
# Weigths[0,0] = 0.01557178453629226
# Weigths[1,0] = 0.03286416844244551
# Weigths[2,0] = 0.0
# Weigths[3,0] = 0.005199428297365306
# Weigths[4,0] = 0.0
# Weigths[5,0] = 0.0
# Weigths[6,0] = 0.019062743784725222
# Weigths[7,0] = 0.0
# Weigths[8,0] = 0.08254596326732963
# Weigths[9,0] = 0.02249061470635193
# Weigths[10,0] = 0.0
# Weigths[11,0] = 0.033683909270754105
# Weigths[12,0] = 0.0
# Weigths[13,0] = 0.0
# Weigths[14,0] = 0.0
# Weigths[15,0] = 0.17188177236297664
# Weigths[16,0] = 0.0153953817468765
# Weigths[17,0] = 0.0
# Weigths[18,0] = 0.0
# Weigths[19,0] = 0.6013042335848828
# Y[0,0] = 0.0
# Y[1,0] = 0.015698073370146316
# Y[2,0] = 0.08473737726761446
# Y[3,0] = 0.0
# Y[4,0] = 0.0030654400935492543
# Y[5,0] = 0.005890827116601965
# Y[6,0] = 0.011646438324930062
# Y[7,0] = 0.0057556112083278245
# Y[8,0] = 0.0
# Y[9,0] = 0.0
# Y[10,0] = 0.006419535636253486
# Y[11,0] = 0.015446735648906917
# Y[12,0] = 0.21353294557481334
# Y[13,0] = 0.005961759919104142
# Y[14,0] = 0.006459118683266276
# Y[15,0] = 0.0
# Y[16,0] = 0.0
# Y[17,0] = 0.1937970749881808
# Y[18,0] = 0.01569807337014632
# Y[19,0] = 0.498526516513875
# F[0,0] = 0.0010064488137970905
# F[1,0] = 0.0019000158782026648
# F[2,0] = 0.0
# F[3,0] = 5.6908216371366616e-05
# F[4,0] = 0.0
# F[5,0] = 0.0
# F[6,0] = 0.0015305486865605199
# F[7,0] = 0.0
# F[8,0] = 0.117454036732659
# F[9,0] = 2.7205023605189615e-05
# F[10,0] = 0.0
# F[11,0] = 0.006839150531143728
# F[12,0] = 0.0
# F[13,0] = 0.0
# F[14,0] = 0.0
# F[15,0] = 0.028118227637040416
# F[16,0] = 0.0012886175194949528
# F[17,0] = 0.0
# F[18,0] = 0.0
# F[19,0] = 0.15167566576352653
# X[0,0] = 0.0
# X[1,0] = 0.0
# X[2,0] = 1.0
# X[3,0] = 0.0
# X[4,0] = 0.0
# X[5,0] = 0.0
# X[6,0] = 1.0
# X[7,0] = 0.0
# X[8,0] = 1.0
# X[9,0] = 1.0
# X[10,0] = 0.0
# x_1[0,0] = 0.009999999999999787
# x_1[1,0] = 0.03286416844244551
# x_1[2,0] = 0.0
# x_1[3,0] = 0.005199428297365306
# x_1[4,0] = 0.0
# x_1[5,0] = 0.0
# x_1[6,0] = 0.009062743784724547
# x_1[7,0] = 0.0
# x_1[8,0] = 0.04999999999999716
# x_1[9,0] = 0.009999999999999787
# x_1[10,0] = 0.0
# x_1[11,0] = 0.033683909270754105
# x_1[12,0] = 0.0
# x_1[13,0] = 0.0
# x_1[14,0] = 0.0
# x_1[15,0] = 0.05000000000000426
# x_1[16,0] = 0.0153953817468765
# x_1[17,0] = 0.0
# x_1[18,0] = 0.0
# x_1[19,0] = 0.19999999999998863
# x_2[0,0] = 0.005571784536292474
# x_2[1,0] = 0.0
# x_2[2,0] = 0.0
# x_2[3,0] = 0.0
# x_2[4,0] = 0.0
# x_2[5,0] = 0.0
# x_2[6,0] = 0.010000000000000675
# x_2[7,0] = 0.0
# x_2[8,0] = 0.03254596326733247
# x_2[9,0] = 0.009999999999999787
# x_2[10,0] = 0.0
# x_2[11,0] = 0.0
# x_2[12,0] = 0.0
# x_2[13,0] = 0.0
# x_2[14,0] = 0.0
# x_2[15,0] = 0.05000000000000426
# x_2[16,0] = 0.0
# x_2[17,0] = 0.0
# x_2[18,0] = 0.0
# x_2[19,0] = 0.19999999999998863
# x_3[0,0] = 0.0
# x_3[1,0] = 0.0
# x_3[2,0] = 0.0
# x_3[3,0] = 0.0
# x_3[4,0] = 0.0
# x_3[5,0] = 0.0
# x_3[6,0] = 0.0
# x_3[7,0] = 0.0
# x_3[8,0] = 0.0
# x_3[9,0] = 0.002490614706352357
# x_3[10,0] = 0.0
# x_3[11,0] = 0.0
# x_3[12,0] = 0.0
# x_3[13,0] = 0.0
# x_3[14,0] = 0.0
# x_3[15,0] = 0.07188177236296811
# x_3[16,0] = 0.0
# x_3[17,0] = 0.0
# x_3[18,0] = 0.0
# x_3[19,0] = 0.20130423358490557
# z_1[0,0] = 0.0010064488137970905
# z_1[1,0] = 0.0019000158782026648
# z_1[2,0] = 0.0
# z_1[3,0] = 5.6908216371366616e-05
# z_1[4,0] = 0.0
# z_1[5,0] = 0.0
# z_1[6,0] = 0.0015305486865605199
# z_1[7,0] = 0.0
# z_1[8,0] = 0.117454036732659
# z_1[9,0] = 2.7205023605189615e-05
# z_1[10,0] = 0.0
# z_1[11,0] = 0.006839150531143728
# z_1[12,0] = 0.0
# z_1[13,0] = 0.0
# z_1[14,0] = 0.0
# z_1[15,0] = 0.028118227637040416
# z_1[16,0] = 0.0012886175194949528
# z_1[17,0] = 0.0
# z_1[18,0] = 0.0
# z_1[19,0] = 0.10540055075611106
# z_2[0,0] = 0.0
# z_2[1,0] = 0.0
# z_2[2,0] = 0.0
# z_2[3,0] = 0.0
# z_2[4,0] = 0.0
# z_2[5,0] = 0.0
# z_2[6,0] = 0.0
# z_2[7,0] = 0.0
# z_2[8,0] = 0.0
# z_2[9,0] = 0.0
# z_2[10,0] = 0.0
# z_2[11,0] = 0.0
# z_2[12,0] = 0.0
# z_2[13,0] = 0.0
# z_2[14,0] = 0.0
# z_2[15,0] = 0.0
# z_2[16,0] = 0.0
# z_2[17,0] = 0.0
# z_2[18,0] = 0.0
# z_2[19,0] = 0.04627511500741548
# z_3[0,0] = 0.0
# z_3[1,0] = 0.0
# z_3[2,0] = 0.0
# z_3[3,0] = 0.0
# z_3[4,0] = 0.0
# z_3[5,0] = 0.0
# z_3[6,0] = 0.0
# z_3[7,0] = 0.0
# z_3[8,0] = 0.0
# z_3[9,0] = 0.0
# z_3[10,0] = 0.0
# z_3[11,0] = 0.0
# z_3[12,0] = 0.0
# z_3[13,0] = 0.0
# z_3[14,0] = 0.0
# z_3[15,0] = 0.0
# z_3[16,0] = 0.0
# z_3[17,0] = 0.0
# z_3[18,0] = 0.0
# z_3[19,0] = 0.0
# [[0.0226278  0.20365018 0.56569495]
#  [0.00725923 0.06533308 0.18148079]
#  [0.01456476 0.13108283 0.36411896]
#  [0.01217834 0.10960506 0.3044585 ]
#  [0.00320983 0.02888846 0.08024573]
#  [0.02104167 0.18937502 0.52604173]
#  [0.00977909 0.08801179 0.24447721]
#  [0.01230718 0.1107646  0.30767946]
#  [0.01538552 0.13846965 0.38463791]
#  [0.0102928  0.09263518 0.25731994]
#  [0.00699043 0.06291388 0.17476079]
#  [0.00914158 0.08227423 0.22853952]
#  [0.01108558 0.09977018 0.27713939]
#  [0.00611723 0.05505503 0.15293063]
#  [0.01245066 0.11205595 0.31126653]
#  [0.01298773 0.11688961 0.32469337]
#  [0.0068788  0.0619092  0.17197   ]
#  [0.00862107 0.07758965 0.2155268 ]
#  [0.00641532 0.05773791 0.1603831 ]
#  [0.00693647 0.06242824 0.17341178]]
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 231 columns and 602 nonzeros
# Model fingerprint: 0x7863555a
# Variable types: 191 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-08, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-03, 1e+00]
# Found heuristic solution: objective 17.5888711
# Presolve removed 176 rows and 55 columns
# Presolve time: 0.00s
# Presolved: 127 rows, 176 columns, 402 nonzeros
# Found heuristic solution: objective 17.5888710
# Variable types: 145 continuous, 31 integer (31 binary)
#
# Root relaxation: objective 2.163717e+00, 91 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.16372    0    7   17.58887    2.16372  87.7%     -    0s
# H    0     0                       2.4318502    2.16372  11.0%     -    0s
# H    0     0                       2.3974183    2.16372  9.75%     -    0s
# H    0     0                       2.3972710    2.16372  9.74%     -    0s
# H    0     0                       2.3694284    2.16372  8.68%     -    0s
#      0     0    2.36358    0    7    2.36943    2.36358  0.25%     -    0s
#      0     0    2.36360    0    5    2.36943    2.36360  0.25%     -    0s
# H    0     0                       2.3645703    2.36360  0.04%     -    0s
#      0     0    2.36436    0    2    2.36457    2.36436  0.01%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 2
#   Implied bound: 3
#   MIR: 2
#   Flow cover: 9
#
# Explored 1 nodes (121 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 2.36457 2.36943 2.39742 ... 17.5889
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.364570257991e+00, best bound 2.364363178079e+00, gap 0.0088%
# Names[0,0] = 1.0
# Names[1,0] = -0.0
# Names[2,0] = 0.0
# Names[3,0] = 1.0
# Names[4,0] = 0.0
# Names[5,0] = -0.0
# Names[6,0] = 1.0
# Names[7,0] = 0.0
# Names[8,0] = 1.0
# Names[9,0] = 1.0
# Names[10,0] = 0.0
# Names[11,0] = 1.0
# Names[12,0] = -0.0
# Names[13,0] = -0.0
# Names[14,0] = 0.0
# Names[15,0] = 1.0
# Names[16,0] = 1.0
# Names[17,0] = -0.0
# Names[18,0] = 1.0
# Names[19,0] = 1.0
# Tickets[0,0] = 1.0
# Tickets[1,0] = 1.0
# Tickets[2,0] = -0.0
# Tickets[3,0] = 1.0
# Tickets[4,0] = -0.0
# Tickets[5,0] = -0.0
# Tickets[6,0] = 1.0
# Tickets[7,0] = -0.0
# Tickets[8,0] = 1.0
# Tickets[9,0] = 1.0
# Tickets[10,0] = -0.0
# Tickets[11,0] = 1.0
# Tickets[12,0] = 0.0
# Tickets[13,0] = 0.0
# Tickets[14,0] = -0.0
# Tickets[15,0] = 1.0
# Tickets[16,0] = 1.0
# Tickets[17,0] = 0.0
# Tickets[18,0] = 1.0
# Tickets[19,0] = 1.0
# Weigths[0,0] = 0.016159750443001275
# Weigths[1,0] = 0.0
# Weigths[2,0] = 0.0
# Weigths[3,0] = 0.0049494392721897975
# Weigths[4,0] = 0.0
# Weigths[5,0] = 0.0
# Weigths[6,0] = 0.020220012841968737
# Weigths[7,0] = 0.0
# Weigths[8,0] = 0.19999999999998863
# Weigths[9,0] = 0.023882313339921638
# Weigths[10,0] = 0.0
# Weigths[11,0] = 0.03166373186962425
# Weigths[12,0] = 0.0
# Weigths[13,0] = 0.0
# Weigths[14,0] = 0.0
# Weigths[15,0] = 0.16434092088533106
# Weigths[16,0] = 0.016018268946849542
# Weigths[17,0] = 0.0
# Weigths[18,0] = 0.03360332853247366
# Weigths[19,0] = 0.4891622338686515
# Y[0,0] = 0.0
# Y[1,0] = 0.017215974346167756
# Y[2,0] = 0.08096220649515667
# Y[3,0] = 0.0
# Y[4,0] = 0.0029600909352058874
# Y[5,0] = 0.006141047310549542
# Y[6,0] = 0.012483935485065066
# Y[7,0] = 0.006342888174515342
# Y[8,0] = 0.1101797919020663
# Y[9,0] = 0.0
# Y[10,0] = 0.006856609953483721
# Y[11,0] = 0.0151239309773857
# Y[12,0] = 0.22445222002286572
# Y[13,0] = 0.0053072300886960345
# Y[14,0] = 0.006719159231619821
# Y[15,0] = 0.0
# Y[16,0] = 0.0
# Y[17,0] = 0.18250871115281908
# Y[18,0] = 0.017215974346167773
# Y[19,0] = 0.38446250500039525
# F[0,0] = 0.0007262766720274628
# F[1,0] = 0.08520112414247534
# F[2,0] = 0.0
# F[3,0] = 0.00028548693882366524
# F[4,0] = 0.0
# F[5,0] = 0.0
# F[6,0] = 0.0014023603665770969
# F[7,0] = 0.0
# F[8,0] = 0.1202605650736781
# F[9,0] = 0.0010602664953618737
# F[10,0] = 0.0
# F[11,0] = 0.005475762704111063
# F[12,0] = 0.0
# F[13,0] = 0.0
# F[14,0] = 0.0
# F[15,0] = 0.012154517925369979
# F[16,0] = 0.0003584708198878378
# F[17,0] = 0.0
# F[18,0] = 0.03360332853247366
# F[19,0] = 0.10133101504544467
# X[0,0] = 0.0
# X[1,0] = 0.0
# X[2,0] = 1.0
# X[3,0] = 0.0
# X[4,0] = 0.0
# X[5,0] = 0.0
# X[6,0] = 1.0
# X[7,0] = 0.0
# X[8,0] = 1.0
# X[9,0] = 1.0
# X[10,0] = 0.0
# x_1[0,0] = 0.009999999999999787
# x_1[1,0] = 0.0
# x_1[2,0] = 0.0
# x_1[3,0] = 0.0049494392721897975
# x_1[4,0] = 0.0
# x_1[5,0] = 0.0
# x_1[6,0] = 0.010000000000000675
# x_1[7,0] = 0.0
# x_1[8,0] = 0.04999999999999716
# x_1[9,0] = 0.009999999999999787
# x_1[10,0] = 0.0
# x_1[11,0] = 0.03166373186962425
# x_1[12,0] = 0.0
# x_1[13,0] = 0.0
# x_1[14,0] = 0.0
# x_1[15,0] = 0.05000000000000426
# x_1[16,0] = 0.0
# x_1[17,0] = 0.0
# x_1[18,0] = 0.010000000000000675
# x_1[19,0] = 0.19999999999998863
# x_2[0,0] = 0.006159750443001488
# x_2[1,0] = 0.0
# x_2[2,0] = 0.0
# x_2[3,0] = 0.0
# x_2[4,0] = 0.0
# x_2[5,0] = 0.0
# x_2[6,0] = 0.010000000000000675
# x_2[7,0] = 0.0
# x_2[8,0] = 0.04999999999999716
# x_2[9,0] = 0.009999999999999787
# x_2[10,0] = 0.0
# x_2[11,0] = 0.0
# x_2[12,0] = 0.0
# x_2[13,0] = 0.0
# x_2[14,0] = 0.0
# x_2[15,0] = 0.05000000000000426
# x_2[16,0] = 0.016018268946849542
# x_2[17,0] = 0.0
# x_2[18,0] = 0.010000000000000675
# x_2[19,0] = 0.19999999999998863
# x_3[0,0] = 0.0
# x_3[1,0] = 0.0
# x_3[2,0] = 0.0
# x_3[3,0] = 0.0
# x_3[4,0] = 0.0
# x_3[5,0] = 0.0
# x_3[6,0] = 0.00022001284196738677
# x_3[7,0] = 0.0
# x_3[8,0] = 0.09999999999999432
# ...
# z_2[0,0] = 0.0
# z_2[1,0] = 0.0
# z_2[2,0] = 0.0
# z_2[3,0] = 0.0
# z_2[4,0] = 0.0
# z_2[5,0] = 0.0
# z_2[6,0] = 0.0
# z_2[7,0] = 0.0
# z_2[8,0] = 0.0
# z_2[9,0] = 0.0
# z_2[10,0] = 0.0
# z_2[11,0] = 0.0
# z_2[12,0] = 0.0
# z_2[13,0] = 0.0
# z_2[14,0] = 0.0
# z_2[15,0] = 0.0
# z_2[16,0] = 0.0
# z_2[17,0] = 0.0
# z_2[18,0] = 0.0
# z_2[19,0] = 0.0
# z_3[0,0] = 0.0
# z_3[1,0] = 0.0
# z_3[2,0] = 0.0
# z_3[3,0] = 0.0
# z_3[4,0] = 0.0
# z_3[5,0] = 0.0
# z_3[6,0] = 0.0
# z_3[7,0] = 0.0
# z_3[8,0] = 0.0
# z_3[9,0] = 0.0
# z_3[10,0] = 0.0
# z_3[11,0] = 0.0
# z_3[12,0] = 0.0
# z_3[13,0] = 0.0
# z_3[14,0] = 0.0
# z_3[15,0] = 0.0
# z_3[16,0] = 0.0
# z_3[17,0] = 0.0
# z_3[18,0] = 0.0
# z_3[19,0] = 0.0
# [[0.00849956 0.07649604 0.21248899]
#  [0.00753161 0.06778445 0.18829014]
#  [0.01681952 0.15137567 0.42048797]
#  [0.00958997 0.08630977 0.23974936]
#  [0.01606327 0.14456946 0.40158182]
#  [0.00325588 0.02930296 0.08139712]
#  [0.00418544 0.03766897 0.10463604]
#  [0.01286485 0.11578369 0.32162136]
#  [0.01497118 0.13474059 0.37427942]
#  [0.01225371 0.11028342 0.30634285]
#  [0.00734999 0.06614992 0.18374977]
#  [0.0149316  0.13438439 0.37328996]
#  [0.01094668 0.09852014 0.27366705]
#  [0.01200085 0.10800761 0.30002114]
#  [0.01826141 0.16435267 0.4565352 ]
#  [0.0130121  0.11710891 0.32530254]
#  [0.03145025 0.28305225 0.78625625]
#  [0.01353756 0.12183808 0.3384391 ]
#  [0.01750846 0.15757611 0.43771143]
#  [0.01964393 0.17679533 0.49109813]]
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 231 columns and 602 nonzeros
# Model fingerprint: 0x67a66ab9
# Variable types: 191 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-08, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e-03, 1e+00]
# Presolve removed 177 rows and 58 columns
# Presolve time: 0.00s
# Presolved: 126 rows, 173 columns, 396 nonzeros
# Variable types: 141 continuous, 32 integer (32 binary)
# Found heuristic solution: objective 3.2821979
#
# Root relaxation: objective 2.591903e+00, 94 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.59190    0    7    3.28220    2.59190  21.0%     -    0s
# H    0     0                       2.8532665    2.59190  9.16%     -    0s
# H    0     0                       2.8457929    2.59190  8.92%     -    0s
# H    0     0                       2.8179751    2.59190  8.02%     -    0s
# H    0     0                       2.7978588    2.77359  0.87%     -    0s
#      0     0    2.77359    0    4    2.79786    2.77359  0.87%     -    0s
#      0     0    2.77360    0    3    2.79786    2.77360  0.87%     -    0s
# H    0     0                       2.7736290    2.77360  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 3
#   Clique: 1
#   MIR: 3
#   Flow cover: 8
#   Flow path: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (113 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2.77363 2.79786 2.84579 3.2822
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.773629029867e+00, best bound 2.773600936475e+00, gap 0.0010%
# Names[0,0] = 1.0
# Names[1,0] = 1.0
# Names[2,0] = 1.0
# Names[3,0] = 1.0
# Names[4,0] = 0.0
# Names[5,0] = -0.0
# Names[6,0] = -0.0
# Names[7,0] = 1.0
# Names[8,0] = 1.0
# Names[9,0] = 1.0
# Names[10,0] = 0.0
# Names[11,0] = 1.0
# Names[12,0] = 1.0
# Names[13,0] = -0.0
# Names[14,0] = 1.0
# Names[15,0] = 1.0
# Names[16,0] = 1.0
# Names[17,0] = 1.0
# Names[18,0] = -0.0
# Names[19,0] = 1.0
# Tickets[0,0] = 1.0
# Tickets[1,0] = 1.0
# Tickets[2,0] = -0.0
# Tickets[3,0] = 1.0
# Tickets[4,0] = -0.0
# Tickets[5,0] = -0.0
# Tickets[6,0] = 0.0
# Tickets[7,0] = 1.0
# Tickets[8,0] = -0.0
# Tickets[9,0] = 1.0
# Tickets[10,0] = 0.0
# Tickets[11,0] = 1.0
# Tickets[12,0] = 1.0
# Tickets[13,0] = 0.0
# Tickets[14,0] = 1.0
# Tickets[15,0] = -0.0
# Tickets[16,0] = 1.0
# Tickets[17,0] = 1.0
# Tickets[18,0] = 0.0
# Tickets[19,0] = 1.0
# Weigths[0,0] = 0.01953713078649568
# Weigths[1,0] = 0.029584320420705662
# Weigths[2,0] = 0.03999999999999915
# Weigths[3,0] = 0.006645271573041529
# Weigths[4,0] = 0.0
# Weigths[5,0] = 0.0
# Weigths[6,0] = 0.0
# Weigths[7,0] = 0.016336586849396924
# Weigths[8,0] = 0.19999999999998863
# Weigths[9,0] = 0.03111144823298251
# Weigths[10,0] = 0.0
# Weigths[11,0] = 0.04221251961803649
# Weigths[12,0] = 0.03999999999999915
# Weigths[13,0] = 0.0
# Weigths[14,0] = 0.03999999999999915
# Weigths[15,0] = 0.20000000000001705
# Weigths[16,0] = 0.021361923291708156
# Weigths[17,0] = 0.0400000000000027
# Weigths[18,0] = 0.0
# Weigths[19,0] = 0.2732107992276272
# Y[0,0] = 0.0
# Y[1,0] = 0.011335163727408958
# Y[2,0] = 0.038827116898583924
# Y[3,0] = 0.0
# Y[4,0] = 0.011439921395072146
# Y[5,0] = 0.003937758720131782
# Y[6,0] = 0.005186399049824911
# Y[7,0] = 0.009124157769956849
# Y[8,0] = 0.07980137268878196
# Y[9,0] = 0.0
# Y[10,0] = 0.00529330142261287
# Y[11,0] = 0.023267790957981867
# Y[12,0] = 0.14364987611504604
# Y[13,0] = 0.006534568140296809
# Y[14,0] = 0.025087092852439274
# Y[15,0] = 0.07774676326674677
# Y[16,0] = 0.0
# Y[17,0] = 0.07974838077024848
# Y[18,0] = 0.011335163727408958
# Y[19,0] = 0.07959014497591047
# F[0,0] = 2.5544464192998884e-05
# F[1,0] = 0.00034787976102556434
# F[2,0] = 0.0
# F[3,0] = 0.0005110770938506863
# F[4,0] = 0.0
# F[5,0] = 0.0
# F[6,0] = 0.0
# F[7,0] = 0.00014306511110084505
# F[8,0] = 0.0
# F[9,0] = 0.0023232488108908336
# F[10,0] = 0.0
# F[11,0] = 0.0017145091276985838
# F[12,0] = 0.03999999999999915
# F[13,0] = 0.0
# F[14,0] = 0.03999999999999915
# F[15,0] = 0.0
# F[16,0] = 0.0009052923245255369
# F[17,0] = 0.0400000000000027
# F[18,0] = 0.0
# F[19,0] = 0.12073101378883794
# X[0,0] = 0.0
# X[1,0] = 0.0
# X[2,0] = 1.0
# X[3,0] = 0.0
# X[4,0] = 0.0
# X[5,0] = 0.0
# X[6,0] = 1.0
# X[7,0] = 0.0
# X[8,0] = 1.0
# X[9,0] = 1.0
# X[10,0] = 0.0
# x_1[0,0] = 0.009537130786495894
# x_1[1,0] = 0.029584320420705662
# x_1[2,0] = 0.009999999999999787
# x_1[3,0] = 0.0
# x_1[4,0] = 0.0
# x_1[5,0] = 0.0
# x_1[6,0] = 0.0
# x_1[7,0] = 0.016336586849396924
# x_1[8,0] = 0.04999999999999716
# x_1[9,0] = 0.009999999999999787
# x_1[10,0] = 0.0
# x_1[11,0] = 0.04221251961803649
# x_1[12,0] = 0.009999999999999787
# x_1[13,0] = 0.0
# x_1[14,0] = 0.009999999999999787
# x_1[15,0] = 0.05000000000000426
# x_1[16,0] = 0.001361923291708582
# x_1[17,0] = 0.010000000000000675
# x_1[18,0] = 0.0
# x_1[19,0] = 0.19999999999998863
# x_2[0,0] = 0.009999999999999787
# x_2[1,0] = 0.0
# x_2[2,0] = 0.009999999999999787
# x_2[3,0] = 0.006645271573041529
# x_2[4,0] = 0.0
# x_2[5,0] = 0.0
# x_2[6,0] = 0.0
# x_2[7,0] = 0.0
# x_2[8,0] = 0.04999999999999716
# x_2[9,0] = 0.009999999999999787
# x_2[10,0] = 0.0
# x_2[11,0] = 0.0
# x_2[12,0] = 0.009999999999999787
# x_2[13,0] = 0.0
# x_2[14,0] = 0.009999999999999787
# x_2[15,0] = 0.05000000000000426
# x_2[16,0] = 0.019999999999999574
# x_2[17,0] = 0.010000000000000675
# x_2[18,0] = 0.0
# x_2[19,0] = 0.07321079922763857
# x_3[0,0] = 0.0
# x_3[1,0] = 0.0
# x_3[2,0] = 0.019999999999999574
# x_3[3,0] = 0.0
# x_3[4,0] = 0.0
# x_3[5,0] = 0.0
# x_3[6,0] = 0.0
# x_3[7,0] = 0.0
# x_3[8,0] = 0.09999999999999432
# x_3[9,0] = 0.011111448232982938
# x_3[10,0] = 0.0
# x_3[11,0] = 0.0
# x_3[12,0] = 0.019999999999999574
# x_3[13,0] = 0.0
# x_3[14,0] = 0.019999999999999574
# x_3[15,0] = 0.10000000000000853
# x_3[16,0] = 0.0
# x_3[17,0] = 0.02000000000000135
# x_3[18,0] = 0.0
# x_3[19,0] = 0.0
# z_1[0,0] = 2.5544464192998884e-05
# z_1[1,0] = 0.00034787976102556434
# z_1[2,0] = 0.0
# z_1[3,0] = 0.0005110770938506863
# z_1[4,0] = 0.0
# z_1[5,0] = 0.0
# z_1[6,0] = 0.0
# z_1[7,0] = 0.00014306511110084505
# z_1[8,0] = 0.0
# z_1[9,0] = 0.0023232488108908336
# z_1[10,0] = 0.0
# z_1[11,0] = 0.0017145091276985838
# z_1[12,0] = 0.03999999999999915
# z_1[13,0] = 0.0
# z_1[14,0] = 0.03999999999999915
# z_1[15,0] = 0.0
# z_1[16,0] = 0.0009052923245255369
# z_1[17,0] = 0.0400000000000027
# z_1[18,0] = 0.0
# z_1[19,0] = 0.12073101378883794
# z_2[0,0] = 0.0
# z_2[1,0] = 0.0
# z_2[2,0] = 0.0
# z_2[3,0] = 0.0
# z_2[4,0] = 0.0
# z_2[5,0] = 0.0
# z_2[6,0] = 0.0
# z_2[7,0] = 0.0
# z_2[8,0] = 0.0
# z_2[9,0] = 0.0
# z_2[10,0] = 0.0
# z_2[11,0] = 0.0
# z_2[12,0] = 0.0
# z_2[13,0] = 0.0
# z_2[14,0] = 0.0
# z_2[15,0] = 0.0
# z_2[16,0] = 0.0
# z_2[17,0] = 0.0
# z_2[18,0] = 0.0
# z_2[19,0] = 0.0
# z_3[0,0] = 0.0
# z_3[1,0] = 0.0
# z_3[2,0] = 0.0
# z_3[3,0] = 0.0
# z_3[4,0] = 0.0
# z_3[5,0] = 0.0
# z_3[6,0] = 0.0
# z_3[7,0] = 0.0
# z_3[8,0] = 0.0
# z_3[9,0] = 0.0
# z_3[10,0] = 0.0
# z_3[11,0] = 0.0
# z_3[12,0] = 0.0
# z_3[13,0] = 0.0
# z_3[14,0] = 0.0
# z_3[15,0] = 0.0
# z_3[16,0] = 0.0
# z_3[17,0] = 0.0
# z_3[18,0] = 0.0
# z_3[19,0] = 0.0
# [[0.0108003  0.09720266 0.27000739]
#  [0.00729086 0.06561774 0.1822715 ]
#  [0.00688717 0.06198453 0.17217925]
#  [0.0261493  0.23534373 0.65373259]
#  [0.00649268 0.05843408 0.16231688]
#  [0.00617913 0.05561215 0.15447819]
#  [0.00793394 0.07140542 0.19834838]
#  [0.00477161 0.04294447 0.1192902 ]
#  [0.00528507 0.04756565 0.13212681]
#  [0.00633074 0.05697665 0.15826848]
#  [0.01355222 0.12196995 0.33880543]
#  [0.00700433 0.063039   0.17510833]
#  [0.00371921 0.03347287 0.09298021]
#  [0.01019112 0.09172012 0.25477811]
#  [0.0201717  0.1815453  0.5042925 ]
#  [0.00940254 0.08462284 0.23506344]
#  [0.00662858 0.05965725 0.16571458]
#  [0.00982231 0.08840083 0.24555786]
#  [0.00863032 0.07767285 0.21575793]
#  [0.0133121  0.1198089  0.3328025 ]]
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 231 columns and 602 nonzeros
# Model fingerprint: 0x264fd3be
# Variable types: 191 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-08, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e-03, 1e+00]
# Found heuristic solution: objective 31.8983722
# Presolve removed 173 rows and 52 columns
# Presolve time: 0.00s
# Presolved: 130 rows, 179 columns, 404 nonzeros
# Found heuristic solution: objective 31.8983714
# Variable types: 145 continuous, 34 integer (34 binary)
#
# Root relaxation: objective 1.433668e+00, 103 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.43367    0    8   31.89837    1.43367  95.5%     -    0s
# H    0     0                       1.6977143    1.43367  15.6%     -    0s
# H    0     0                       1.6610889    1.43367  13.7%     -    0s
# H    0     0                       1.6589748    1.43367  13.6%     -    0s
# H    0     0                       1.6280873    1.57550  3.23%     -    0s
#      0     0    1.57550    0    4    1.62809    1.57550  3.23%     -    0s
# H    0     0                       1.6259039    1.61285  0.80%     -    0s
# H    0     0                       1.6128627    1.61285  0.00%     -    0s
#      0     0    1.61285    0    1    1.61286    1.61285  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Implied bound: 1
#   MIR: 4
#   Flow cover: 5
#   Flow path: 2
#   Relax-and-lift: 2
#
# Explored 1 nodes (130 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1.61286 1.62809 31.8984 31.8984
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.612862691355e+00, best bound 1.612852759123e+00, gap 0.0006%
# Names[0,0] = 1.0
# Names[1,0] = 1.0
# Names[2,0] = -0.0
# Names[3,0] = 1.0
# Names[4,0] = 0.0
# Names[5,0] = -0.0
# Names[6,0] = 0.0
# Names[7,0] = 1.0
# Names[8,0] = 1.0
# Names[9,0] = 1.0
# Names[10,0] = 0.0
# Names[11,0] = 1.0
# Names[12,0] = -0.0
# Names[13,0] = 0.0
# Names[14,0] = -0.0
# Names[15,0] = 1.0
# Names[16,0] = 1.0
# Names[17,0] = -0.0
# Names[18,0] = 0.0
# Names[19,0] = 1.0
# Tickets[0,0] = 1.0
# Tickets[1,0] = 1.0
# Tickets[2,0] = 1.0
# Tickets[3,0] = 1.0
# Tickets[4,0] = 0.0
# Tickets[5,0] = -0.0
# Tickets[6,0] = -0.0
# Tickets[7,0] = 1.0
# Tickets[8,0] = 1.0
# Tickets[9,0] = 1.0
# Tickets[10,0] = 0.0
# Tickets[11,0] = 1.0
# Tickets[12,0] = 1.0
# Tickets[13,0] = 0.0
# Tickets[14,0] = 0.0
# Tickets[15,0] = 1.0
# Tickets[16,0] = 1.0
# Tickets[17,0] = 1.0
# Tickets[18,0] = 0.0
# Tickets[19,0] = 1.0
# Weigths[0,0] = 0.01961360770619472
# Weigths[1,0] = 0.031333033241683746
# Weigths[2,0] = 0.0
# Weigths[3,0] = 0.00641418692618962
# Weigths[4,0] = 0.0
# Weigths[5,0] = 0.0
# Weigths[6,0] = 0.0
# Weigths[7,0] = 0.01593648935628878
# Weigths[8,0] = 0.11654221410533397
# Weigths[9,0] = 0.030838892364380397
# Weigths[10,0] = 0.0
# Weigths[11,0] = 0.04402314426408064
# Weigths[12,0] = 0.0
# Weigths[13,0] = 0.0
# Weigths[14,0] = 0.0
# Weigths[15,0] = 0.11672906535275712
# Weigths[16,0] = 0.019783836172940304
# Weigths[17,0] = 0.0
# Weigths[18,0] = 0.0
# Weigths[19,0] = 0.5987855305101509
# Y[0,0] = 0.0
# Y[1,0] = 0.01302036796542248
# Y[2,0] = 0.07987785413362118
# Y[3,0] = 0.0
# Y[4,0] = 0.011055046139810353
# Y[5,0] = 0.003826414287007883
# Y[6,0] = 0.005024930082626892
# Y[7,0] = 0.008851344369634907
# Y[8,0] = 0.0
# Y[9,0] = 0.0
# Y[10,0] = 0.0046589555869546535
# Y[11,0] = 0.022865170537244895
# Y[12,0] = 0.18298943652488234
# Y[13,0] = 0.007151168810479843
# Y[14,0] = 0.013316089416527774
# Y[15,0] = 0.0
# Y[16,0] = 0.0
# Y[17,0] = 0.1104687650898824
# Y[18,0] = 0.013020367965422469
# Y[19,0] = 0.38665214516491325
# F[0,0] = 0.0009825627001575632
# F[1,0] = 0.001419152901181775
# F[2,0] = 0.03999999999999915
# F[3,0] = 0.000255065163088819
# F[4,0] = 0.0
# F[5,0] = 0.0
# F[6,0] = 0.0
# F[7,0] = 0.01706916071512606
# F[8,0] = 0.08345778589465465
# F[9,0] = 0.0030828032238683356
# F[10,0] = 0.0
# F[11,0] = 0.002998530224304241
# F[12,0] = 0.03999999999999915
# F[13,0] = 0.0
# F[14,0] = 0.0
# F[15,0] = 0.08327093464725994
# F[16,0] = 0.001182998340260727
# F[17,0] = 0.0400000000000027
# F[18,0] = 0.0
# F[19,0] = 0.28030627602841307
# X[0,0] = 0.0
# X[1,0] = 0.0
# X[2,0] = 1.0
# X[3,0] = 0.0
# X[4,0] = 0.0
# X[5,0] = 0.0
# X[6,0] = 1.0
# X[7,0] = 0.0
# X[8,0] = 1.0
# X[9,0] = 1.0
# X[10,0] = 0.0
# x_1[0,0] = 0.009999999999999782
# x_1[1,0] = 0.031333033241683746
# x_1[2,0] = 0.0
# x_1[3,0] = 0.00641418692618962
# x_1[4,0] = 0.0
# x_1[5,0] = 0.0
# x_1[6,0] = 0.0
# x_1[7,0] = 0.01593648935628878
# x_1[8,0] = 0.04999999999999716
# x_1[9,0] = 0.009999999999999787
# x_1[10,0] = 0.0
# x_1[11,0] = 0.04402314426408064
# x_1[12,0] = 0.0
# x_1[13,0] = 0.0
# x_1[14,0] = 0.0
# x_1[15,0] = 0.05000000000000426
# x_1[16,0] = 0.019783836172940304
# x_1[17,0] = 0.0
# x_1[18,0] = 0.0
# x_1[19,0] = 0.19999999999998863
# x_2[0,0] = 0.009613607706194937
# x_2[1,0] = 0.0
# x_2[2,0] = 0.0
# x_2[3,0] = 0.0
# x_2[4,0] = 0.0
# x_2[5,0] = 0.0
# x_2[6,0] = 0.0
# x_2[7,0] = 0.0
# x_2[8,0] = 0.04999999999999716
# x_2[9,0] = 0.009999999999999787
# x_2[10,0] = 0.0
# x_2[11,0] = 0.0
# x_2[12,0] = 0.0
# x_2[13,0] = 0.0
# x_2[14,0] = 0.0
# x_2[15,0] = 0.05000000000000426
# x_2[16,0] = 0.0
# x_2[17,0] = 0.0
# x_2[18,0] = 0.0
# x_2[19,0] = 0.19999999999998863
# x_3[0,0] = 0.0
# x_3[1,0] = 0.0
# x_3[2,0] = 0.0
# x_3[3,0] = 0.0
# x_3[4,0] = 0.0
# x_3[5,0] = 0.0
# x_3[6,0] = 0.0
# x_3[7,0] = 0.0
# x_3[8,0] = 0.016542214105339653
# x_3[9,0] = 0.010838892364380823
# x_3[10,0] = 0.0
# x_3[11,0] = 0.0
# x_3[12,0] = 0.0
# x_3[13,0] = 0.0
# x_3[14,0] = 0.0
# x_3[15,0] = 0.016729065352748596
# x_3[16,0] = 0.0
# x_3[17,0] = 0.0
# x_3[18,0] = 0.0
# x_3[19,0] = 0.19878553051017295
# z_1[0,0] = 0.0009825627001573967
# z_1[1,0] = 0.001419152901181761
# z_1[2,0] = 0.03999999999999915
# z_1[3,0] = 0.00025506516308854144
# z_1[4,0] = 0.0
# z_1[5,0] = 0.0
# z_1[6,0] = 0.0
# z_1[7,0] = 0.017069160715125972
# z_1[8,0] = 0.07269850318032549
# z_1[9,0] = 0.003082803223868197
# z_1[10,0] = 0.0
# z_1[11,0] = 0.002998530224304241
# z_1[12,0] = 0.03999999999999915
# z_1[13,0] = 0.0
# z_1[14,0] = 0.0
# z_1[15,0] = 0.08327093464725994
# z_1[16,0] = 0.0011829983402606992
# z_1[17,0] = 0.0400000000000027
# z_1[18,0] = 0.0
# z_1[19,0] = 0.1153780735138341
# z_2[0,0] = 0.0
# z_2[1,0] = 0.0
# z_2[2,0] = 0.0
# z_2[3,0] = 0.0
# z_2[4,0] = 0.0
# z_2[5,0] = 0.0
# z_2[6,0] = 0.0
# z_2[7,0] = 0.0
# z_2[8,0] = 0.01075928271432916
# z_2[9,0] = 0.0
# z_2[10,0] = 0.0
# z_2[11,0] = 0.0
# z_2[12,0] = 0.0
# z_2[13,0] = 0.0
# z_2[14,0] = 0.0
# z_2[15,0] = 0.0
# z_2[16,0] = 0.0
# z_2[17,0] = 0.0
# z_2[18,0] = 0.0
# z_2[19,0] = 0.1649282025145789
# z_3[0,0] = 0.0
# z_3[1,0] = 0.0
# z_3[2,0] = 0.0
# z_3[3,0] = 0.0
# z_3[4,0] = 0.0
# z_3[5,0] = 0.0
# z_3[6,0] = 0.0
# z_3[7,0] = 0.0
# z_3[8,0] = 0.0
# z_3[9,0] = 0.0
# z_3[10,0] = 0.0
# z_3[11,0] = 0.0
# z_3[12,0] = 0.0
# z_3[13,0] = 0.0
# z_3[14,0] = 0.0
# z_3[15,0] = 0.0
# z_3[16,0] = 0.0
# z_3[17,0] = 0.0
# z_3[18,0] = 0.0
# z_3[19,0] = 0.0

# %%
fig = plt.subplots(figsize=(20,15))
for i in range(20):
    fig = plt.subplot(4,5,i+1)
    plt.title(names[i])
    plt.plot(range(49), w_f[i,:])
    plt.plot(range(48), w_t[i,:])
    
plt.suptitle("Portfolio Example", fontsize=30)
plt.savefig("Portfolio Example.jpg")
